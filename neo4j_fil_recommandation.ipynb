# %% [markdown]
# <!-- image from image -->
# ![image](images/exemple.png)

# %% [markdown]
# ## 🎬 **Projet : Recommandation de Films avec Neo4j & Graph Data Science**
#
# ### 🔍 Objectif général :
#
# Concevoir un système de recommandation de films en exploitant une base de données orientée graphe. L’algorithme s’appuie sur les notes attribuées par les utilisateurs aux films pour proposer des contenus personnalisés.
#
# ---
#
# ## 1. 📦 Chargement des données
#
# Les données utilisées proviennent du dataset **MovieLens 1M**, comprenant :
#
# * une liste de films avec titres et genres,
# * des utilisateurs avec âge, sexe, profession, etc.,
# * les notes attribuées par les utilisateurs aux films.
#
# ---
#
# ## 2. 🧩 Modélisation dans Neo4j
#
# Les données sont importées dans Neo4j sous forme de graphe avec :
#
# * des **nœuds `User`** pour représenter les utilisateurs,
# * des **nœuds `Movie`** pour représenter les films,
# * des **relations `RATED`** qui relient un utilisateur à un film avec une note.
#
# Cette modélisation permet d’exprimer facilement les relations complexes comme la co-notation ou les préférences croisées.
#
# ---
#
# ## 3. 🔄 Recherche de films similaires
#
# L’idée ici est qu’un film est **similaire** à un autre si de nombreux utilisateurs les ont **tous deux bien notés**. On recherche donc des films co-notés positivement par les mêmes utilisateurs, et on les classe par fréquence.
#
# ---
#
# ## 4. 👥 Similarité entre utilisateurs
#
# On projette un graphe entre les utilisateurs et les films qu’ils ont notés, puis on calcule une **similarité entre utilisateurs** basée sur leurs comportements (notes attribuées).
# Cela permet de repérer des **profils proches**.
#
# ---
#
# ## 5. 🧠 Recommandation collaborative
#
# Une fois les utilisateurs similaires identifiés, on recommande à un utilisateur les films **que ses voisins proches ont bien notés**, mais qu’il n’a pas encore vus.
#
# Les recommandations sont pondérées selon :
#
# * la **note** attribuée par l’utilisateur voisin,
# * et la **similarité** entre les deux utilisateurs.
#
# ---
#
# ## 6. ✅ Vérification des goûts réels
#
# On récupère les films déjà notés par l’utilisateur pour comparer les recommandations à ses préférences connues. Cela permet une **évaluation qualitative** des suggestions proposées.
#
# ---
#
# ## 7. 🎞️ Recommandation par genre
#
# Une méthode alternative consiste à recommander des films en se basant sur les **genres préférés** de l’utilisateur. On analyse ses notes positives et on en déduit ses genres favoris.
# Ensuite, on propose des films du même genre qu’il n’a pas encore vus.
#
# ---
#
# ## 🧾 Conclusion
#
# Ce projet démontre l'efficacité des bases de données orientées graphes pour la **recommandation personnalisée**, grâce à :
#
# * la flexibilité du modèle graphe,
# * les algorithmes de **similarité** (nœuds ou genres),
# * et l'exploitation intuitive des relations complexes.
#
# Il peut être étendu à d’autres domaines comme la musique, l’e-commerce ou les réseaux sociaux.
#
# ---
#
# Souhaites-tu que je t’ajoute une **introduction générale** ou une **conclusion académique** selon ton niveau d’étude (Master, Licence, etc.) ?

# %%
import pandas as pd
import numpy as np
from graphdatascience import GraphDataScience

# %%
# Neo4j Connection details
DB_ULR = 'bolt://localhost:7687'
DB_USER = 'neo4j' 
DB_PASS = 'test1234'
gds = GraphDataScience(DB_ULR, auth=(DB_USER, DB_PASS))
gds.version()
# Out:
# '2.13.3'

# %%
nodes = gds.run_cypher('''
    MATCH (n)
    RETURN COUNT(n)
''') 
nodes.head()
# Out:
#    COUNT(n)
# 0      9923

# %%
movies = pd.read_csv('datasets/movies.dat', sep='::', encoding="ISO-8859-1", names=['MovieID','Title','Genres', 'Actors', 'Realizations', 'Date'], engine='python')
ratings = pd.read_csv('datasets/ratings.dat', sep='::', encoding="ISO-8859-1",names=['UserID','MovieID','Rating','Timestamp'], engine='python')
users = pd.read_csv('datasets/users.dat', sep='::', encoding="ISO-8859-1",names=['UserID','Name','Gender','Age','Occupation','Zip_code'], engine='python')

# %%
print("************** Les films *******")
display(movies.head())
print("************** Les utilisateurs *******")
display(users.head())
print("************** Les notes *******")
display(ratings.head())
# Out:
# ************** Les films *******
#    MovieID                        Title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         Genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                               Actors  \
# 0                         Tina Stewart|Jessica Smith
# 1  Richard Sanchez|David Walker|Carol Rodriguez|J...
# 2  Nicholas Ramsey|Donna Williams|David Huerta|Ch...
# 3                                      Curtis Wright
# 4                      David Rogers|Stanley Galloway
#
#                      Realizations    Date
# 0  Jeremy Hendricks|Sonya Edwards  1995.0
# 1    Edward Williams|Keith Hudson  1995.0
# 2       Kyle Luna|Daniel Gonzalez  1995.0
# 3                Derrick Campbell  1995.0
# 4                 Howard Martinez  1995.0
# ************** Les utilisateurs *******
#    UserID            Name Gender  Age  Occupation  Zip_code
# 0       1   Mary Campbell      F   35          27     92606
# 1       2      Larry Shaw      M   15          22      6265
# 2       3   Suzanne Quinn      F   27          27     54865
# 3       4  Monique Hughes      F   62           2      1871
# 4       5    Justin Stone      M   47          21     99193
# ************** Les notes *******
#    UserID  MovieID  Rating   Timestamp
# 0   99476   104374     3.5  1467897440
# 1  107979     2634     4.0   994007728
# 2  155372     1614     3.0  1097887531
# 3   65225     7153     4.0  1201382275
# 4   79161      500     5.0  1488915363

# %%
def create_user_nodes(gds, users_df):
    '''
    Crée des noeuds d'utilisateur dans la base de données Neo4j.
        :param gds: Instance de GraphDataScience
        :param users_df: DataFrame contenant les informations des utilisateurs
        :return: Résultat de la requête Cypher
    '''
    # Ajouter la contrainte (si elle n'existe pas encore)
    gds.run_cypher('''
        CREATE CONSTRAINT IF NOT EXISTS 
        FOR (n:User) 
        REQUIRE n.id IS NODE KEY
    ''')

    # Inserer les Users
    result = gds.run_cypher('''
        UNWIND $data AS row
        MERGE (u:User {id: row.UserID})
        SET u.gender = row.Gender,
            u.age = row.Age
        RETURN count(*) AS users_created
    ''', params={'data': users_df.to_dict('records')})

    return result


def create_movie_nodes(gds, movies_df):
    '''
    Crée des noeuds de film dans la base de données Neo4j.
        :param gds: Instance de GraphDataScience
        :param movies_df: DataFrame contenant les informations des films
        :return: Résultat de la requête Cypher
    '''
    # Ajouter la contrainte (si elle n'existe pas encore)
    gds.run_cypher('''
        CREATE CONSTRAINT IF NOT EXISTS 
        FOR (n:Movie) 
        REQUIRE n.id IS NODE KEY
    ''')

    # Inserer les Movies
    result = gds.run_cypher('''
        UNWIND $data AS row
        MERGE (m:Movie {id: row.MovieID})
        SET m.title = row.Title,
            m.genres = row.Genres
        RETURN count(*) AS movies_created
    ''', params={'data': movies_df.to_dict('records')})

    return result

# %%
# Créer les utilisateurs
res_users = create_user_nodes(gds, users)
print(res_users)

# Créer les films
res_movies = create_movie_nodes(gds, movies)
print(res_movies)
# Out:
#    users_created
# 0         162541
#    movies_created
# 0           62423

# %%
nodes = gds.run_cypher('''
    MATCH (u:User) RETURN count(u);
''') 
nodes.head()
# Out:
#    count(u)
# 0    162541

# %%
nodes = gds.run_cypher('''
    MATCH (m:Movie) RETURN count(m);
''')
nodes.head()
# Out:
#    count(m)
# 0     62457

# %%
def create_rated_relationships(gds, ratings_df, chunk_size=200):
    i = 1
    for chunk in np.array_split(ratings_df, chunk_size):
        print(f"Chunk {i}/{chunk_size}")
        result = gds.run_cypher('''
            UNWIND $data AS row
            MATCH (u:User {id: row.UserID}), (m:Movie {id: row.MovieID})
            MERGE (u)-[r:RATED]->(m)
            SET r.rating = row.Rating
            RETURN count(*) AS created
        ''', params={'data': chunk.to_dict('records')})
        print(result.head())
        i += 1
    return result

# %%
# Créer les relations RATED
res_rated = create_rated_relationships(gds, ratings)
print(res_rated)
# Out:
# Chunk 1/200
#    created
# 0       50
# Chunk 2/200
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#    created
# 0       50
# Chunk 3/200
#    created
# 0       50
# Chunk 4/200
#    created
# 0       50
# Chunk 5/200
#    created
# 0       50
# Chunk 6/200
#    created
# 0       50
# Chunk 7/200
#    created
# 0       50
# Chunk 8/200
#    created
# 0       50
# Chunk 9/200
#    created
# 0       50
# Chunk 10/200
#    created
# 0       50
# Chunk 11/200
#    created
# 0       50
# Chunk 12/200
#    created
# 0       50
# Chunk 13/200
#    created
# 0       50
# Chunk 14/200
#    created
# 0       50
# Chunk 15/200
#    created
# 0       50
# Chunk 16/200
#    created
# 0       50
# Chunk 17/200
#    created
# 0       50
# Chunk 18/200
#    created
# 0       50
# Chunk 19/200
#    created
# 0       50
# Chunk 20/200
#    created
# 0       50
# Chunk 21/200
#    created
# 0       50
# Chunk 22/200
#    created
# 0       50
# Chunk 23/200
#    created
# 0       50
# Chunk 24/200
#    created
# 0       50
# Chunk 25/200
#    created
# 0       50
# Chunk 26/200
#    created
# 0       50
# Chunk 27/200
#    created
# 0       50
# Chunk 28/200
#    created
# 0       50
# Chunk 29/200
#    created
# 0       50
# Chunk 30/200
#    created
# 0       50
# Chunk 31/200
#    created
# 0       50
# Chunk 32/200
#    created
# 0       50
# Chunk 33/200
#    created
# 0       50
# Chunk 34/200
#    created
# 0       50
# Chunk 35/200
#    created
# 0       50
# Chunk 36/200
#    created
# 0       50
# Chunk 37/200
#    created
# 0       50
# Chunk 38/200
#    created
# 0       50
# Chunk 39/200
#    created
# 0       50
# Chunk 40/200
#    created
# 0       50
# Chunk 41/200
#    created
# 0       50
# Chunk 42/200
#    created
# 0       50
# Chunk 43/200
#    created
# 0       50
# Chunk 44/200
#    created
# 0       50
# Chunk 45/200
#    created
# 0       50
# Chunk 46/200
#    created
# 0       50
# Chunk 47/200
#    created
# 0       50
# Chunk 48/200
#    created
# 0       50
# Chunk 49/200
#    created
# 0       50
# Chunk 50/200
#    created
# 0       50
# Chunk 51/200
#    created
# 0       50
# Chunk 52/200
#    created
# 0       50
# Chunk 53/200
#    created
# 0       50
# Chunk 54/200
#    created
# 0       50
# Chunk 55/200
#    created
# 0       50
# Chunk 56/200
#    created
# 0       50
# Chunk 57/200
#    created
# 0       50
# Chunk 58/200
#    created
# 0       50
# Chunk 59/200
#    created
# 0       50
# Chunk 60/200
#    created
# 0       50
# Chunk 61/200
#    created
# 0       50
# Chunk 62/200
#    created
# 0       50
# Chunk 63/200
#    created
# 0       50
# Chunk 64/200
#    created
# 0       50
# Chunk 65/200
#    created
# 0       50
# Chunk 66/200
#    created
# 0       50
# Chunk 67/200
#    created
# 0       50
# Chunk 68/200
#    created
# 0       50
# Chunk 69/200
#    created
# 0       50
# Chunk 70/200
#    created
# 0       50
# Chunk 71/200
#    created
# 0       50
# Chunk 72/200
#    created
# 0       50
# Chunk 73/200
#    created
# 0       50
# Chunk 74/200
#    created
# 0       50
# Chunk 75/200
#    created
# 0       50
# Chunk 76/200
#    created
# 0       50
# Chunk 77/200
#    created
# 0       50
# Chunk 78/200
#    created
# 0       50
# Chunk 79/200
#    created
# 0       50
# Chunk 80/200
#    created
# 0       50
# Chunk 81/200
#    created
# 0       50
# Chunk 82/200
#    created
# 0       50
# Chunk 83/200
#    created
# 0       50
# Chunk 84/200
#    created
# 0       50
# Chunk 85/200
#    created
# 0       50
# Chunk 86/200
#    created
# 0       50
# Chunk 87/200
#    created
# 0       50
# Chunk 88/200
#    created
# 0       50
# Chunk 89/200
#    created
# 0       50
# Chunk 90/200
#    created
# 0       50
# Chunk 91/200
#    created
# 0       50
# Chunk 92/200
#    created
# 0       50
# Chunk 93/200
#    created
# 0       50
# Chunk 94/200
#    created
# 0       50
# Chunk 95/200
#    created
# 0       50
# Chunk 96/200
#    created
# 0       50
# Chunk 97/200
#    created
# 0       50
# Chunk 98/200
#    created
# 0       50
# Chunk 99/200
#    created
# 0       50
# Chunk 100/200
#    created
# 0       50
# Chunk 101/200
#    created
# 0       50
# Chunk 102/200
#    created
# 0       50
# Chunk 103/200
#    created
# 0       50
# Chunk 104/200
#    created
# 0       50
# Chunk 105/200
#    created
# 0       50
# Chunk 106/200
#    created
# 0       50
# Chunk 107/200
#    created
# 0       50
# Chunk 108/200
#    created
# 0       50
# Chunk 109/200
#    created
# 0       50
# Chunk 110/200
#    created
# 0       50
# Chunk 111/200
#    created
# 0       50
# Chunk 112/200
#    created
# 0       50
# Chunk 113/200
#    created
# 0       50
# Chunk 114/200
#    created
# 0       50
# Chunk 115/200
#    created
# 0       50
# Chunk 116/200
#    created
# 0       50
# Chunk 117/200
#    created
# 0       50
# Chunk 118/200
#    created
# 0       50
# Chunk 119/200
#    created
# 0       50
# Chunk 120/200
#    created
# 0       50
# Chunk 121/200
#    created
# 0       50
# Chunk 122/200
#    created
# 0       50
# Chunk 123/200
#    created
# 0       50
# Chunk 124/200
#    created
# 0       50
# Chunk 125/200
#    created
# 0       50
# Chunk 126/200
#    created
# 0       50
# Chunk 127/200
#    created
# 0       50
# Chunk 128/200
#    created
# 0       50
# Chunk 129/200
#    created
# 0       50
# Chunk 130/200
#    created
# 0       50
# Chunk 131/200
#    created
# 0       50
# Chunk 132/200
#    created
# 0       50
# Chunk 133/200
#    created
# 0       50
# Chunk 134/200
#    created
# 0       50
# Chunk 135/200
#    created
# 0       50
# Chunk 136/200
#    created
# 0       50
# Chunk 137/200
#    created
# 0       50
# Chunk 138/200
#    created
# 0       50
# Chunk 139/200
#    created
# 0       50
# Chunk 140/200
#    created
# 0       50
# Chunk 141/200
#    created
# 0       50
# Chunk 142/200
#    created
# 0       50
# Chunk 143/200
#    created
# 0       50
# Chunk 144/200
#    created
# 0       50
# Chunk 145/200
#    created
# 0       50
# Chunk 146/200
#    created
# 0       50
# Chunk 147/200
#    created
# 0       50
# Chunk 148/200
#    created
# 0       50
# Chunk 149/200
#    created
# 0       50
# Chunk 150/200
#    created
# 0       50
# Chunk 151/200
#    created
# 0       50
# Chunk 152/200
#    created
# 0       50
# Chunk 153/200
#    created
# 0       50
# Chunk 154/200
#    created
# 0       50
# Chunk 155/200
#    created
# 0       50
# Chunk 156/200
#    created
# 0       50
# Chunk 157/200
#    created
# 0       50
# Chunk 158/200
#    created
# 0       50
# Chunk 159/200
#    created
# 0       50
# Chunk 160/200
#    created
# 0       50
# Chunk 161/200
#    created
# 0       50
# Chunk 162/200
#    created
# 0       50
# Chunk 163/200
#    created
# 0       50
# Chunk 164/200
#    created
# 0       50
# Chunk 165/200
#    created
# 0       50
# Chunk 166/200
#    created
# 0       50
# Chunk 167/200
#    created
# 0       50
# Chunk 168/200
#    created
# 0       50
# Chunk 169/200
#    created
# 0       50
# Chunk 170/200
#    created
# 0       50
# Chunk 171/200
#    created
# 0       50
# Chunk 172/200
#    created
# 0       50
# Chunk 173/200
#    created
# 0       50
# Chunk 174/200
#    created
# 0       50
# Chunk 175/200
#    created
# 0       50
# Chunk 176/200
#    created
# 0       50
# Chunk 177/200
#    created
# 0       50
# Chunk 178/200
#    created
# 0       50
# Chunk 179/200
#    created
# 0       50
# Chunk 180/200
#    created
# 0       50
# Chunk 181/200
#    created
# 0       50
# Chunk 182/200
#    created
# 0       50
# Chunk 183/200
#    created
# 0       50
# Chunk 184/200
#    created
# 0       50
# Chunk 185/200
#    created
# 0       50
# Chunk 186/200
#    created
# 0       50
# Chunk 187/200
#    created
# 0       50
# Chunk 188/200
#    created
# 0       50
# Chunk 189/200
#    created
# 0       50
# Chunk 190/200
#    created
# 0       50
# Chunk 191/200
#    created
# 0       50
# Chunk 192/200
#    created
# 0       50
# Chunk 193/200
#    created
# 0       50
# Chunk 194/200
#    created
# 0       50
# Chunk 195/200
#    created
# 0       50
# Chunk 196/200
#    created
# 0       50
# Chunk 197/200
#    created
# 0       50
# Chunk 198/200
#    created
# 0       50
# Chunk 199/200
#    created
# 0       50
# Chunk 200/200
#    created
# 0       50
#    created
# 0       50

# %%
nodes = gds.run_cypher('''
    MATCH (u:User)-[r:RATED]->(m:Movie) RETURN count(r);
''')
nodes.head()
# Out:
#    count(r)
# 0   1010173

# %% [markdown]
# <!-- image from image -->
# ![image](images/view_relation.png)

# %%
def get_similar_movies(title):
    """
    Récupère la liste des films similaires à un film donné en fonction des utilisateurs 
    ayant noté les deux films avec la note maximale (5).

    Cette fonction interroge la base de données Neo4j pour trouver les films qui partagent 
    des utilisateurs en commun ayant attribué une note de 5 à ces films et au film cible.

    Args:
        title (str): Le titre exact du film pour lequel trouver des films similaires.

    Returns:
        pd.DataFrame: Un DataFrame contenant :
            - title (str): Le titre des films similaires.
            - genres (str): Les genres des films similaires.
            - common_users (int): Le nombre d'utilisateurs ayant noté les deux films avec la note 5.
    """
    
    query = '''
    MATCH (m1:Movie)-[r1:RATED]-(u:User)-[r2:RATED]-(m2:Movie)
    WHERE m1.title = $title
      AND m2.title <> $title
      AND r1.rating = 5 
      AND r2.rating = 5
    RETURN m2.title AS title, m2.genres AS genres, count(DISTINCT u) AS common_users
    ORDER BY common_users DESC
    '''

    result = gds.run_cypher(query, params={'title': title})
    print(f"******** Les films similaires à {title} ******** ")
    return result


similar_movies = get_similar_movies('1408')
similar_movies.head(10)
# Out:
# ******** Les films similaires à 1408 ********
# Empty DataFrame
# Columns: [title, genres, common_users]
# Index: []

# %%
def get_similar_movies(title, min_rating=5):
    """
    Retourne les films similaires basés sur les utilisateurs ayant noté les deux films avec une note minimale.

    Args:
        title (str): Le titre du film pour lequel on veut trouver des films similaires.
        min_rating (int): La note minimale que les utilisateurs doivent avoir donnée pour être considérés.

    Returns:
        pd.DataFrame: Liste des films similaires avec le nombre d'utilisateurs en commun.
    """
    
    query = '''
    MATCH (m1:Movie)-[r1:RATED]-(u:User)-[r2:RATED]-(m2:Movie)
    WHERE m1.title = $title
      AND m2.title <> $title
      AND r1.rating >= $min_rating 
      AND r2.rating >= $min_rating
    RETURN m2.title AS title, m2.genres AS genres, count(DISTINCT u) AS common_users
    ORDER BY common_users DESC
    '''

    result = gds.run_cypher(query, params={'title': title, 'min_rating': min_rating})
    print(f"******** Les films similaires à {title} avec une note minimale de {min_rating} ******** ")
    return result


similar_movies = get_similar_movies('I Am Legend', min_rating=4)
similar_movies.head(10)
# Out:
# ******** Les films similaires à I Am Legend avec une note minimale de 4 ********
# Empty DataFrame
# Columns: [title, genres, common_users]
# Index: []

# %%
gds.run_cypher("CALL gds.graph.drop('myGraph', false)")

create_projection = gds.run_cypher('''
CALL gds.graph.project(
  'myGraph',
  ['User', 'Movie'],
  {
    RATED: {
      properties: 'rating'
    }
  }
);
''')

create_projection.head()
# Out:
#                                       nodeProjection  \
# 0  {'User': {'label': 'User', 'properties': {}}, ...
#
#                               relationshipProjection graphName  nodeCount  \
# 0  {'RATED': {'aggregation': 'DEFAULT', 'orientat...   myGraph     224998
#
#    relationshipCount  projectMillis
# 0            1010173            702

# %%
gds.run_cypher("CALL gds.graph.drop('myGraphFiltered', false)")

create_projection = gds.run_cypher('''
CALL gds.graph.project.cypher(
  'myGraphFiltered',
  '
  MATCH (u:User)
  WHERE COUNT { (u)-[:RATED]->() } >= 1000
  RETURN id(u) AS id
  ',
  '
  MATCH (u1:User)-[r:RATED]->(m:Movie)
  RETURN id(u1) AS source, id(m) AS target, r.rating AS rating
  ',
  {validateRelationships: false}
)
''')

create_projection.head()
# Out:
#                                            nodeQuery  \
# 0  MATCH (u:User)\n  WHERE COUNT { (u)-[:RATED]->...
#
#                                    relationshipQuery        graphName  \
# 0  MATCH (u1:User)-[r:RATED]->(m:Movie)\n  RETURN...  myGraphFiltered
#
#    nodeCount  relationshipCount  projectMillis
# 0         41                  0            331

# %%
# MATCH (u:User {id: 1})-[:RATED]->(m1:Movie)
# WITH collect(DISTINCT m1.genres) AS genres_list
# UNWIND genres_list AS genre
# MATCH (m2:Movie)
# WHERE genre IN m2.genres AND NOT EXISTS {
#     MATCH (:User {id: 1})-[:RATED]->(m2)
# }
# RETURN m2.title, m2.genres
# LIMIT 5

# get user similarity
def get_user_similarity(user_id: int) -> pd.DataFrame:
    """
    Récupère les utilisateurs similaires à un utilisateur donné en utilisant l'algorithme 
    de similarité de noeuds GDS (Node Similarity) sur la projection 'myGraphFiltered'.

    Args:
        user_id (int): L'ID de l'utilisateur (attribut logique 'id').

    Returns:
        pd.DataFrame: Un DataFrame contenant :
            - similar_user_id (int) : ID logique de l'utilisateur similaire.
            - similarity (float) : Score de similarité.
    """
    # Étape 1 : Récupérer l'ID interne Neo4j à partir de l'ID logique
    node_id_query = '''
    MATCH (u:User {id: $user_id})
    RETURN id(u) AS nodeId
    '''
    node_id_df = gds.run_cypher(node_id_query, params={'user_id': user_id})
    
    if node_id_df.empty:
        print(f"⚠️ Aucun utilisateur trouvé avec l'id logique {user_id}")
        return pd.DataFrame()

    node_id = node_id_df.iloc[0]['nodeId']

    # Étape 2 : Calculer les similarités avec l'algorithme Node Similarity
    similarity_query = '''
    CALL gds.nodeSimilarity.stream('myGraphFiltered')
    YIELD node1, node2, similarity
    WHERE node1 = $node_id OR node2 = $node_id
    RETURN 
        CASE 
            WHEN node1 = $node_id THEN gds.util.asNode(node2).id 
            ELSE gds.util.asNode(node1).id 
        END AS similar_user_id,
        similarity
    ORDER BY similarity DESC
    LIMIT 10
    '''
    result_df = gds.run_cypher(similarity_query, params={'node_id': node_id})

    print(f"✅ Utilisateurs similaires à l'utilisateur logique {user_id} :")
    return result_df

similar_users = get_user_similarity(3)
similar_users.head(10)
# Out:
# ✅ Utilisateurs similaires à l'utilisateur logique 3 :
# Empty DataFrame
# Columns: [similar_user_id, similarity]
# Index: []

# %%
# Calcul de la similarité entre tous les utilisateurs du graphe 'myGraphFiltered'
query = '''
CALL gds.nodeSimilarity.stream('myGraphFiltered')
YIELD node1, node2, similarity
RETURN 
    gds.util.asNode(node1).id AS user_id_1,
    gds.util.asNode(node2).id AS user_id_2,
    similarity
ORDER BY similarity DESC, user_id_1, user_id_2
'''

# Exécution de la requête Cypher
users_similarity = gds.run_cypher(query)

# Affichage des premières lignes du DataFrame
users_similarity.head()
# Out:
# Empty DataFrame
# Columns: [user_id_1, user_id_2, similarity]
# Index: []

# %%
# Create Similar relationship
i=1
for chunk in np.array_split(users_similarity.query('UserID1>UserID2'),10):
  print(i)
  create_similar = gds.run_cypher('''
    unwind $data as row
    match (u1:User{id: row.UserID1}), (u2:User{id: row.UserID2})
    merge (u1)-[r:SIMILAR]->(u2)
    set r.Similarity=row.similarity
    return count(*) as create_rated
    ''', params = {'data': chunk.to_dict('records')})
  i = i+1
create_similar.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File /opt/anaconda3/lib/python3.12/collections/__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File /opt/anaconda3/lib/python3.12/collections/__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'UserID1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'UserID1'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Create Similar relationship
#       2 i=1
# ----> 3 for chunk in np.array_split(users_similarity.query('UserID1>UserID2'),10):
#       4   print(i)
#       5   create_similar = gds.run_cypher('''
#       6     unwind $data as row
#       7     match (u1:User{id: row.UserID1}), (u2:User{id: row.UserID2})
#    (...)
#      10     return count(*) as create_rated
#      11     ''', params = {'data': chunk.to_dict('records')})
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:418, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     416     raise SyntaxError("only a single expression is allowed")
#     417 expr = node.body[0]
# --> 418 return self.visit(expr, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     420 def visit_Expr(self, node, **kwargs):
# --> 421     return self.visit(node.value, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:532, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 def visit_BinOp(self, node, **kwargs):
# --> 532     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533     left, right = self._maybe_downcast_constants(left, right)
#     534     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:452, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     450 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451     if left is None:
# --> 452         left = self.visit(node.left, side="left")
#     453     if right is None:
#     454         right = self.visit(node.right, side="right")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'UserID1' is not defined

# %%
# Check similar movies
similar_movies_for_user = gds.run_cypher('''
    MATCH (u1:User)-[r1:SIMILAR]-(u2)-[r2:RATED]-(m:Movie)
    WHERE id(u1)=$id
    AND NOT ( (u1)-[]-(m))
    RETURN m.Title,m.Genres,Sum(r1.Similarity*r2.Rating)/sum(r1.Similarity)+log(count(r2)) as score
    ORDER BY score DESC
''',params = {'id':4725})
similar_movies_for_user.head(10)

# %%
# Check actual movies
movies_for_user = gds.run_cypher('''
    MATCH (u1:User)-[r:RATED]-(m:Movie)
  WHERE id(u1)=$id
  RETURN m.Title,m.Genres,r.Rating as rating
  ORDER BY rating DESC
''',params = {'id':4725})
movies_for_user.head(10)
